# %%
import scipy.io
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib notebook
import ast
import numpy as np
from scipy.ndimage import gaussian_filter1d
from scipy.signal import argrelextrema
import pandas as pd

# %%
df = pd.read_csv('Take 2022-03-07 08.25.00 PM.csv', skiprows = 6,usecols=[1,3,6,9,12])
# Y,Y.1,Y.2,Y.3
# fin mid,key, fin tip, ,UR5
# df['diff_ur_fin'] = df['Y']-df['Y.1']
# df['diff_ur_fin_filtered'] = gaussian_filter1d(df['diff_ur_fin'], sigma=2, truncate=4)

# %%
start = 1000
end = 10000

name = ['Y','Y.1','Y.2']
for n in name:
#     df[n+'f'] = gaussian_filter1d(df[n], sigma=1, truncate=6)
    df[n+'f'] = df[n]
plt.subplot(4,1,1)
plt.plot(df['Y'][start:end])
plt.subplot(4,1,2)
plt.plot(df['Y.1'][start:end])
plt.subplot(4,1,3)
plt.plot(df['Y.2'][start:end])

plt.show()

# %%
fig = plt.figure(2,figsize=(6, 4.5))
start = 2880
end = 3200
plt.plot(df['Time'][start:end],df['Y.1'][start:end])
plt.xlabel('Time (s)',fontsize=15)
plt.ylabel('Piano key displacement (m)',fontsize=15)
plt.title('Ground Truth',fontsize=20)
fig.savefig('v1.jpg',bbox_inches = 'tight', format='jpg')
# Out:
# <img src="data:image/png;base64,..." width="600.0000423855282">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19620\2508965798.py in <module>
#       2 start = 2880
#       3 end = 3200
# ----> 4 plt.plot(df['Time'][start:end],df['Y.1'][start:end])
#       5 plt.xlabel('Time (s)',fontsize=15)
#       6 plt.ylabel('Piano key displacement (m)',fontsize=15)
#
# NameError: name 'df' is not defined

# %%
fig = plt.figure(6,figsize=(6, 4.5))
start = 2900
end = 3200
plt.plot(df['Time'][start:end],df['Y.1'][start:end])
plt.xlabel('Time (s)',fontsize=15)
plt.ylabel('Piano key displacement (m)',fontsize=15)
plt.title('Ground Truth',fontsize=20)
# fig.savefig('v2.jpg',bbox_inches = 'tight', format='jpg')
# Out:
# <img src="data:image/png;base64,..." width="600.0000423855282">
# Text(0.5, 1.0, 'Ground Truth')

# %%
fig = plt.figure(3,figsize=(6, 4.5))
start = 4080
end = 4220
plt.plot(df['Time'][start:end],df['Y.1'][start:end])
plt.xlabel('Time (s)',fontsize=15)
plt.ylabel('Piano key displacement (m)',fontsize=15)
plt.title('Ground Truth',fontsize=20)
fig.savefig('v2.jpg',bbox_inches = 'tight', format='jpg')
# Out:
# <img src="data:image/png;base64,..." width="600.0000423855282">

# %%
fig = plt.figure(4,figsize=(6, 4.5))
start = 4800
end = 4900
plt.plot(df['Time'][start:end],df['Y.1'][start:end])
plt.xlabel('Time (s)',fontsize=15)
plt.ylabel('Piano key displacement (m)',fontsize=15)
plt.title('Ground Truth',fontsize=20)
fig.savefig('v3.jpg',bbox_inches = 'tight', format='jpg')
# Out:
# <img src="data:image/png;base64,..." width="600.0000423855282">

# %%
mat = scipy.io.loadmat('../model/videl_data.mat')

# %%
mat = scipy.io.loadmat('../model/videl_data.mat')
fig = plt.figure(5,figsize=(6, 4.5))
start = 0
end = 50000
# plt.plot(mat['time'][start:end],mat['x2'][start:end])
plt.plot(mat['time'],mat['x2'])
plt.xlabel('Time (s)',fontsize=15)
plt.ylabel('Piano key displacement (m)',fontsize=15)
plt.title('Model prediction',fontsize=20)
fig.savefig('s1.jpg',bbox_inches = 'tight', format='jpg')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
mat = scipy.io.loadmat('../model/videl_data.mat')
fig = plt.figure(6,figsize=(6, 4.5))
start = 0
end = 50000
# plt.plot(mat['time'][start:end],mat['x2'][start:end])
plt.plot(mat['time'],mat['x2'])
plt.xlabel('Time (s)',fontsize=15)
plt.ylabel('Piano key displacement (m)',fontsize=15)
plt.title('Model prediction',fontsize=20)
fig.savefig('s2.jpg',bbox_inches = 'tight', format='jpg')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
mat = scipy.io.loadmat('../model/videl_data.mat')
fig = plt.figure(7,figsize=(6, 4.5))
start = 0
end = 400
plt.plot(mat['time'][start:end],mat['x2'][start:end])
# plt.plot(mat['time'],mat['x2'])
plt.xlabel('Time (s)',fontsize=15)
plt.ylabel('Piano key displacement (m)',fontsize=15)
plt.title('Model prediction',fontsize=20)
fig.savefig('s3.jpg',bbox_inches = 'tight', format='jpg')
# Out:
# <img src="data:image/png;base64,..." width="600.0000423855282">
